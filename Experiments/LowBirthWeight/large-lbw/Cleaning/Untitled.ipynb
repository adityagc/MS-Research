# %%
for i in range(16):
    print(i, 'lin', i, '-1111')
# Out:
# (0, 'lin', 0, '-1111')
# (1, 'lin', 1, '-1111')
# (2, 'lin', 2, '-1111')
# (3, 'lin', 3, '-1111')
# (4, 'lin', 4, '-1111')
# (5, 'lin', 5, '-1111')
# (6, 'lin', 6, '-1111')
# (7, 'lin', 7, '-1111')
# (8, 'lin', 8, '-1111')
# (9, 'lin', 9, '-1111')
# (10, 'lin', 10, '-1111')
# (11, 'lin', 11, '-1111')
# (12, 'lin', 12, '-1111')
# (13, 'lin', 13, '-1111')
# (14, 'lin', 14, '-1111')
# (15, 'lin', 15, '-1111')
